# %%
import numpy as np

img = np.load('img.npy')
img_transient = np.load('img_transient.npy')

# %%
print(img.shape)
print(img_transient.shape)
print(img.dtype)
print(img_transient.dtype)
# Out:
# (256, 256, 3)
# (256, 256, 2048, 3)
# float32
# float32

# %%
print(np.min(img_transient), np.max(img_transient))
# Out:
# 0.0 0.12170109

# %%
import matplotlib.pyplot as plt

plt.imshow(img / np.max(img))

# %%
plt.imshow(img_transient[:, 10, :, 0], cmap='hot')

# %%
plt.plot(img_transient[10, 10, :, 0])
